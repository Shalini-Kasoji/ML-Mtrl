# %%
import pandas as pd
import numpy as np

#checking version
print('Numpy: ',np.__version__)
print('Pandas: ',pd.__version__)
# Out:
# Numpy:  1.15.4
# Pandas:  0.23.4

# %%
#reading csv files
#Wrong
bikes=pd.read_table('C:\\Users\\admin\\EDA_Datasets\\bikeshare.csv',header=None)
print(bikes.head())
# Out:
#                                                    0
# 0  instant,dteday,season,yr,mnth,hr,holiday,weekd...
# 1  1,2011-01-01,1,0,1,0,0,6,0,1,0.24,0.2879,0.81,...
# 2  2,2011-01-01,1,0,1,1,0,6,0,1,0.22,0.2727,0.8,0...
# 3  3,2011-01-01,1,0,1,2,0,6,0,1,0.22,0.2727,0.8,0...
# 4  4,2011-01-01,1,0,1,3,0,6,0,1,0.24,0.2879,0.75,...

# %%
#Wrong
bikes=pd.read_table('C:\\Users\\admin\\EDA_Datasets\\bikeshare.csv',header=1)
print(bikes.head())
# Out:
#   1,2011-01-01,1,0,1,0,0,6,0,1,0.24,0.2879,0.81,0,3,13,16
# 0  2,2011-01-01,1,0,1,1,0,6,0,1,0.22,0.2727,0.8,0...
# 1  3,2011-01-01,1,0,1,2,0,6,0,1,0.22,0.2727,0.8,0...
# 2  4,2011-01-01,1,0,1,3,0,6,0,1,0.24,0.2879,0.75,...
# 3  5,2011-01-01,1,0,1,4,0,6,0,1,0.24,0.2879,0.75,...
# 4  6,2011-01-01,1,0,1,5,0,6,0,2,0.24,0.2576,0.75,...

# %%
#Right
bikes=pd.read_table('C:\\Users\\admin\\EDA_Datasets\\bikeshare.csv',header=0)
print(bikes.head())
# Out:
#   instant,dteday,season,yr,mnth,hr,holiday,weekday,workingday,weathersit,temp,atemp,hum,windspeed,casual,registered,cnt
# 0  1,2011-01-01,1,0,1,0,0,6,0,1,0.24,0.2879,0.81,...
# 1  2,2011-01-01,1,0,1,1,0,6,0,1,0.22,0.2727,0.8,0...
# 2  3,2011-01-01,1,0,1,2,0,6,0,1,0.22,0.2727,0.8,0...
# 3  4,2011-01-01,1,0,1,3,0,6,0,1,0.24,0.2879,0.75,...
# 4  5,2011-01-01,1,0,1,4,0,6,0,1,0.24,0.2879,0.75,...

# %%
#Case 1 treats headings as just another data row. Case 2 treats the 1st data row as the column header. 
#Case 3 gets the header right (row 0), but reads each row as a single column (Nb. the other two make that same mistake).

#Load the file "bikeshare.csv" into a DataFrame named bikes, and confirm that it was loaded properly

bikes=pd.read_table('C:\\Users\\admin\\EDA_Datasets\\bikeshare.csv',header=0,sep=',')
print(bikes.head())
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
#Reading Excel Files
from pandas import ExcelFile

ef=pd.read_excel('C:\\Users\\admin\EDA_Datasets\Iris.xls')
ef
# Out:
#      sepal length  sepal width  petal length  petal width            iris  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# ...

# %%
#Load the above file without the unwanted columns:
ef=pd.read_excel('C:\\Users\\admin\EDA_Datasets\Iris.xls',sheet_name='Iris',header=0,usecols=[0,1,2,3,4])
ef
# Out:
#      sepal length  sepal width  petal length  petal width            iris
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# ...

# %%
#Data Profiling
#Counts
bikes['season'].value_counts()
# Out:
# 3    4496
# 2    4409
# 1    4242
# 4    4232
# Name: season, dtype: int64

# %%
print('instant:',bikes['instant'].min(),'to',bikes['instant'].max())
# Out:
# instant: 1 to 17379

# %%
#atemp_level
atemp_level=pd.cut(bikes['atemp'],bins=4)
print(atemp_level)
# Out:
# 0           (0.25, 0.5]
# 1           (0.25, 0.5]
# 2           (0.25, 0.5]
# 3           (0.25, 0.5]
# 4           (0.25, 0.5]
# 5           (0.25, 0.5]
# 6           (0.25, 0.5]
# 7           (0.25, 0.5]
# 8           (0.25, 0.5]
# 9           (0.25, 0.5]
# 10          (0.25, 0.5]
# 11          (0.25, 0.5]
# 12          (0.25, 0.5]
# 13          (0.25, 0.5]
# 14          (0.25, 0.5]
# 15          (0.25, 0.5]
# 16          (0.25, 0.5]
# 17          (0.25, 0.5]
# 18          (0.25, 0.5]
# 19          (0.25, 0.5]
# 20          (0.25, 0.5]
# 21          (0.25, 0.5]
# 22          (0.25, 0.5]
# 23          (0.25, 0.5]
# 24          (0.25, 0.5]
# 25          (0.25, 0.5]
# 26          (0.25, 0.5]
# 27          (0.25, 0.5]
# 28          (0.25, 0.5]
# 29          (0.25, 0.5]
#               ...
# 17349    (-0.001, 0.25]
# 17350       (0.25, 0.5]
# 17351    (-0.001, 0.25]
# 17352    (-0.001, 0.25]
# 17353    (-0.001, 0.25]
# 17354    (-0.001, 0.25]
# 17355    (-0.001, 0.25]
# ...

# %%
print(atemp_level.value_counts())
# Out:
# (0.25, 0.5]       7507
# (0.5, 0.75]       7223
# (-0.001, 0.25]    1952
# (0.75, 1.0]        697
# Name: atemp, dtype: int64

# %%
print(type(atemp_level))
# Out:
# <class 'pandas.core.series.Series'>

# %%
atemp_level=pd.cut(bikes['atemp'],bins=4,labels=['cool','mild','warm','hot'])
atemp_level.value_counts()
# Out:
# mild    7507
# warm    7223
# cool    1952
# hot      697
# Name: atemp, dtype: int64
