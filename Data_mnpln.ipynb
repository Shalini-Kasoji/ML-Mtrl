# %%
import  os
os.getcwd()
os.chdir('E:/Prep/Predc')
os.getcwd()
# Out:
# 'E:\\Prep\\Predc'

# %%
pwd
# Out:
# 'E:\\Prep\\Predc'

# %%
import pandas as pd
mydata=pd.read_csv('students.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-3-54cc0a886583> in <module>
#       1 import pandas as pd
# ----> 2 mydata=pd.read_csv('students.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
pwd

# %%
import pandas as pd
mydata=pd.read_excel('students.xls')
mydata
# Out:
#     ID Last Name First Name            City           State  Gender  \
# 0   29     DOE14      JOE14    Buenos Aires       Argentina       0
# 1   13     DOE07      JOE07           Varna        Bulgaria       0
# 2    9     DOE04     JANE04        Montreal          Canada       1
# 3   24     DOE14     JANE14         Beijing           China       1
# 4   17     DOE09     JANE09       Amsterdam         Holland       1
# 5    6     DOE04      JOE04        Tel Aviv          Israel       0
# 6   18     DOE10     JANE10          Mexico          Mexico       1
# 7   14     DOE08      JOE08          Moscow          Russia       0
# 8   25     DOE11      JOE11       Stockholm          Sweden       0
# 9    1     DOE01     JANE01     Los Angeles      California       1
# 10   2     DOE02     JANE02          Sedona         Arizona       1
# 11   3     DOE01      JOE01          Elmira        New York       0
# 12   4     DOE02      JOE02       Lackawana        New York       0
# ...

# %%
mydata.columns
# Out:
# Index(['ID', 'Last Name', 'First Name', 'City', 'State', 'Gender',
#        'Student Status', 'Major', 'Country', 'Age', 'SAT',
#        'Average score (grade)', 'Height (in)',
#        'Newspaper readership (times/wk)'],
#       dtype='object')

# %%
mydata.head()
# Out:
#    ID Last Name First Name          City      State  Gender  Student Status  \
# 0  29     DOE14      JOE14  Buenos Aires  Argentina       0               1
# 1  13     DOE07      JOE07         Varna   Bulgaria       0               1
# 2   9     DOE04     JANE04      Montreal     Canada       1               0
# 3  24     DOE14     JANE14       Beijing      China       1               0
# 4  17     DOE09     JANE09     Amsterdam    Holland       1               0
#
#    Major    Country  Age   SAT  Average score (grade)  Height (in)  \
# 0      2  Argentina   30  2279              85.000000           72
# 1      2   Bulgaria   30  1637              79.337239           63
# 2      1     Canada   18  1813              91.000000           62
# 3      1      China   18  1643              79.000000           65
# 4      1    Holland   19  1494              75.000000           60
#
#    Newspaper readership (times/wk)
# 0                                3
# ...

# %%
mydata.head(10)

# %%
mydata.head(-10)

# %%
mydata.tail()

# %%
mydata.tail(10)

# %%
mydata.tail(-10)

# %%
mydata.iloc[0:10, ] # First 10 rows

# %%
mydata.iloc[0:10,0:3] # First 10 rows of data of the first 3 variables

# %%
#Checking missing data
#Checking missing in the columns
mydata.isnull().sum()

# %%
mydata.isnull().sum().sum()

# %%
mydata.isnull().values

# %%
mydata.info()

# %%
mydata.isnull().sum(axis=0)

# %%
mydata.isnull().sum(axis=1) #Row wise checking missing data

# %%
mydata.columns

# %%
# changing cols with rename() 
mydata = mydata.rename(columns = { 
                                  "First Name": "First_Name", 
                                  "Last Name": "Last_Name",
                                  "Student Status": "Student_Status"})
mydata.columns
# Out:
# Index(['ID', 'Last_Name', 'First_Name', 'City', 'State', 'Gender',
#        'Student_Status', 'Major', 'Country', 'Age', 'SAT',
#        'Average score (grade)', 'Height (in)',
#        'Newspaper readership (times/wk)'],
#       dtype='object')

# %%
# changing cols with rename() 
mydata = mydata.rename(columns = { 
                                  "First Name": "First_Name", 
                                  "Last Name": "Last_Name",
                                  "Student Status": "Student_Status"
                                  "Average score (grade)": "Scores" })
# Out:
#   File "<ipython-input-10-3284ee70cc82>", line 6
#     "Average score (grade)": "Scores" })
#                            ^
# SyntaxError: invalid syntax

# %%
mydata.columns

# %%
#Assigning value labels
mydata['Gender'].replace([0,1],['Male','Female'],inplace=True)
mydata['Student_Status'].replace([0,1],['Undergraduate','Graduate'],inplace=True)
mydata['Major'].replace([0,1,2],['Econ','Math','Politics'],inplace=True)
mydata.head()
# Out:
#    ID Last_Name First_Name          City      State  Gender Student_Status  \
# 0  29     DOE14      JOE14  Buenos Aires  Argentina    Male       Graduate
# 1  13     DOE07      JOE07         Varna   Bulgaria    Male       Graduate
# 2   9     DOE04     JANE04      Montreal     Canada  Female  Undergraduate
# 3  24     DOE14     JANE14       Beijing      China  Female  Undergraduate
# 4  17     DOE09     JANE09     Amsterdam    Holland  Female  Undergraduate
#
#       Major    Country  Age   SAT  Average score (grade)  Height (in)  \
# 0  Politics  Argentina   30  2279              85.000000           72
# 1  Politics   Bulgaria   30  1637              79.337239           63
# 2      Math     Canada   18  1813              91.000000           62
# 3      Math      China   18  1643              79.000000           65
# 4      Math    Holland   19  1494              75.000000           60
#
#    Newspaper readership (times/wk)   Age_rec
# 0                                3     Adult
# ...

# %%
#Recoding variables - Grouping the values
import pandas as pd

bins=[13,19,29,39]
labels=['Teenager','Young','Adult']
mydata['Age_rec']=pd.cut(mydata.Age,bins,labels=labels)
mydata
# Out:
#     ID Last_Name First_Name            City           State  Gender  \
# 0   29     DOE14      JOE14    Buenos Aires       Argentina    Male
# 1   13     DOE07      JOE07           Varna        Bulgaria    Male
# 2    9     DOE04     JANE04        Montreal          Canada  Female
# 3   24     DOE14     JANE14         Beijing           China  Female
# 4   17     DOE09     JANE09       Amsterdam         Holland  Female
# 5    6     DOE04      JOE04        Tel Aviv          Israel    Male
# 6   18     DOE10     JANE10          Mexico          Mexico  Female
# 7   14     DOE08      JOE08          Moscow          Russia    Male
# 8   25     DOE11      JOE11       Stockholm          Sweden    Male
# 9    1     DOE01     JANE01     Los Angeles      California  Female
# 10   2     DOE02     JANE02          Sedona         Arizona  Female
# 11   3     DOE01      JOE01          Elmira        New York    Male
# 12   4     DOE02      JOE02       Lackawana        New York    Male
# ...

# %%
mydata['Age_rec'].value_counts()
# Out:
# Adult       11
# Teenager    10
# Young        9
# Name: Age_rec, dtype: int64

# %%
std_df=mydata.copy()
std_df
# Out:
#     ID Last_Name First_Name            City           State  Gender  \
# 0   29     DOE14      JOE14    Buenos Aires       Argentina    Male
# 1   13     DOE07      JOE07           Varna        Bulgaria    Male
# 2    9     DOE04     JANE04        Montreal          Canada  Female
# 3   24     DOE14     JANE14         Beijing           China  Female
# 4   17     DOE09     JANE09       Amsterdam         Holland  Female
# 5    6     DOE04      JOE04        Tel Aviv          Israel    Male
# 6   18     DOE10     JANE10          Mexico          Mexico  Female
# 7   14     DOE08      JOE08          Moscow          Russia    Male
# 8   25     DOE11      JOE11       Stockholm          Sweden    Male
# 9    1     DOE01     JANE01     Los Angeles      California  Female
# 10   2     DOE02     JANE02          Sedona         Arizona  Female
# 11   3     DOE01      JOE01          Elmira        New York    Male
# 12   4     DOE02      JOE02       Lackawana        New York    Male
# ...

# %%
std_df.columns
# Out:
# Index(['ID', 'Last_Name', 'First_Name', 'City', 'State', 'Gender',
#        'Student_Status', 'Major', 'Country', 'Age', 'SAT',
#        'Average score (grade)', 'Height (in)',
#        'Newspaper readership (times/wk)', 'Age_rec'],
#       dtype='object')

# %%
std_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 15 columns):
# ID                                 30 non-null int64
# Last_Name                          30 non-null object
# First_Name                         30 non-null object
# City                               30 non-null object
# State                              30 non-null object
# Gender                             30 non-null object
# Student_Status                     30 non-null object
# Major                              30 non-null object
# Country                            30 non-null object
# Age                                30 non-null int64
# SAT                                30 non-null int64
# Average score (grade)              30 non-null float64
# Height (in)                        30 non-null int64
# Newspaper readership (times/wk)    30 non-null int64
# Age_rec                            30 non-null category
# ...

# %%
import random
rvn1=random.sample(range(1,31),30)
rvn1
# Out:
# [4,
#  29,
#  15,
#  21,
#  6,
#  18,
#  10,
#  1,
#  19,
#  24,
#  3,
#  11,
#  25,
#  17,
#  28,
#  22,
#  7,
#  2,
#  20,
#  5,
#  26,
#  16,
#  27,
#  30,
#  8,
#  9,
#  14,
#  23,
#  12,
#  13]

# %%
rvn2=random.sample(range(1,31),30)
rvn2
# Out:
# [18,
#  28,
#  14,
#  6,
#  9,
#  11,
#  7,
#  20,
#  24,
#  15,
#  26,
#  1,
#  27,
#  29,
#  5,
#  3,
#  2,
#  25,
#  12,
#  23,
#  22,
#  8,
#  10,
#  19,
#  21,
#  30,
#  16,
#  17,
#  13,
#  4]

# %%
sd=pd.DataFrame(rvn1)
sd
# Out:
#      0
# 0    4
# 1   29
# 2   15
# 3   21
# 4    6
# 5   18
# 6   10
# 7    1
# 8   19
# 9   24
# 10   3
# 11  11
# 12  25
# 13  17
# 14  28
# 15  22
# 16   7
# 17   2
# 18  20
# 19   5
# 20  26
# 21  16
# 22  27
# 23  30
# 24   8
# 25   9
# 26  14
# 27  23
# 28  12
# 29  13

# %%
sd1=pd.DataFrame(rvn2)
sd1
# Out:
#      0
# 0   18
# 1   28
# 2   14
# 3    6
# 4    9
# 5   11
# 6    7
# 7   20
# 8   24
# 9   15
# 10  26
# 11   1
# 12  27
# 13  29
# 14   5
# 15   3
# 16   2
# 17  25
# 18  12
# 19  23
# 20  22
# 21   8
# 22  10
# 23  19
# 24  21
# 25  30
# 26  16
# 27  17
# 28  13
# 29   4

# %%
std_df1 = pd.concat([sd, sd1], axis=1,ignore_index=False)
std_df1.columns=['rvn1','rvn2']
std_df1
# Out:
#     rvn1  rvn2
# 0      4    18
# 1     29    28
# 2     15    14
# 3     21     6
# 4      6     9
# 5     18    11
# 6     10     7
# 7      1    20
# 8     19    24
# 9     24    15
# 10     3    26
# 11    11     1
# 12    25    27
# 13    17    29
# 14    28     5
# 15    22     3
# 16     7     2
# 17     2    25
# 18    20    12
# 19     5    23
# 20    26    22
# 21    16     8
# 22    27    10
# 23    30    19
# 24     8    21
# 25     9    30
# 26    14    16
# 27    23    17
# 28    12    13
# 29    13     4

# %%
stdn_df = pd.concat([std_df, std_df1], axis=1,ignore_index=False)
stdn_df.head()
# Out:
#    ID Last_Name First_Name          City      State  Gender Student_Status  \
# 0  29     DOE14      JOE14  Buenos Aires  Argentina    Male       Graduate
# 1  13     DOE07      JOE07         Varna   Bulgaria    Male       Graduate
# 2   9     DOE04     JANE04      Montreal     Canada  Female  Undergraduate
# 3  24     DOE14     JANE14       Beijing      China  Female  Undergraduate
# 4  17     DOE09     JANE09     Amsterdam    Holland  Female  Undergraduate
#
#       Major    Country  Age   SAT  Average score (grade)  Height (in)  \
# 0  Politics  Argentina   30  2279              85.000000           72
# 1  Politics   Bulgaria   30  1637              79.337239           63
# 2      Math     Canada   18  1813              91.000000           62
# 3      Math      China   18  1643              79.000000           65
# 4      Math    Holland   19  1494              75.000000           60
#
#    Newspaper readership (times/wk)   Age_rec  rvn1  rvn2
# ...

# %%
#selecting columns which starts with 'S'
mydata1=stdn_df[stdn_df.columns[pd.Series(stdn_df.columns).str.startswith('S')]]
mydata1
# Out:
#              State Student_Status   SAT
# 0        Argentina       Graduate  2279
# 1         Bulgaria       Graduate  1637
# 2           Canada  Undergraduate  1813
# 3            China  Undergraduate  1643
# 4          Holland  Undergraduate  1494
# 5           Israel       Graduate  1786
# 6           Mexico       Graduate  2248
# 7           Russia       Graduate  1512
# 8           Sweden  Undergraduate  1919
# 9       California       Graduate  2263
# 10         Arizona  Undergraduate  2006
# 11        New York       Graduate  2221
# 12        New York       Graduate  1716
# 13            Ohio       Graduate  1701
# 14  North Carolina       Graduate  1577
# 15          Kansas  Undergraduate  1842
# 16        New York       Graduate  2041
# 17     Mississippi  Undergraduate  1787
# 18        Virginia       Graduate  1513
# 19        New York  Undergraduate  1338
# 20            Utah  Undergraduate  1821
# 21     Puerto Rico       Graduate  1923
# ...

# %%
#selecting columns which ends with 'e'
mydata2=stdn_df[stdn_df.columns[pd.Series(stdn_df.columns).str.endswith('e')]]
mydata2
# Out:
#    Last_Name First_Name           State  Age
# 0      DOE14      JOE14       Argentina   30
# 1      DOE07      JOE07        Bulgaria   30
# 2      DOE04     JANE04          Canada   18
# 3      DOE14     JANE14           China   18
# 4      DOE09     JANE09         Holland   19
# 5      DOE04      JOE04          Israel   25
# 6      DOE10     JANE10          Mexico   31
# 7      DOE08      JOE08          Russia   30
# 8      DOE11      JOE11          Sweden   19
# 9      DOE01     JANE01      California   30
# 10     DOE02     JANE02         Arizona   19
# 11     DOE01      JOE01        New York   26
# 12     DOE02      JOE02        New York   33
# 13     DOE03      JOE03            Ohio   37
# 14     DOE05      JOE05  North Carolina   39
# 15     DOE03     JANE03          Kansas   21
# 16     DOE05     JANE05        New York   33
# 17     DOE06      JOE06     Mississippi   18
# 18     DOE06     JANE06        Virginia   38
# 19     DOE07     JANE07        New York   21
# ...

# %%
#Selecting Variables contain 'I' in their names
mydata3=stdn_df[stdn_df.columns[pd.Series(stdn_df.columns).str.contains('Ave')]]
mydata3
# Out:
#     Average score (grade)
# 0               85.000000
# 1               79.337239
# 2               91.000000
# 3               79.000000
# 4               75.000000
# 5               69.000000
# 6               95.423560
# 7               70.279498
# 8               88.000000
# 9               67.000000
# 10              63.000000
# 11              78.113285
# 12              77.808587
# 13              65.000000
# 14              95.882515
# 15              87.000000
# 16              71.000000
# 17              81.525285
# 18              78.936614
# 19              82.385960
# 20              80.000000
# 21              95.000000
# 22              67.000000
# 23              82.000000
# 24              89.000000
# 25              95.835542
# 26              88.000000
# 27              64.000000
# 28              79.499360
# 29              92.000000

# %%
#Selecting Variables ----------Wrong
mydata4=stdn_df.loc[['ID','Average score (grade)']]
mydata4
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-8690db1ea3a7> in <module>
#       1 #Selecting Variables
# ----> 2 mydata4=stdn_df.loc[['ID','Average score (grade)']]
#       3 mydata4
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1899                     raise ValueError('Cannot index with multidimensional key')
#    1900
# -> 1901                 return self._getitem_iterable(key, axis=axis)
#    1902
#    1903             # nested tuple slicing
#
# ...

# %%
columns = ['ID', 'Average score (grade)']
mydata4 = pd.DataFrame(stdn_df, columns=columns)
mydata4
# Out:
#     ID  Average score (grade)
# 0   29              85.000000
# 1   13              79.337239
# 2    9              91.000000
# 3   24              79.000000
# 4   17              75.000000
# 5    6              69.000000
# 6   18              95.423560
# 7   14              70.279498
# 8   25              88.000000
# 9    1              67.000000
# 10   2              63.000000
# 11   3              78.113285
# 12   4              77.808587
# 13   5              65.000000
# 14   7              95.882515
# 15   8              87.000000
# 16  10              71.000000
# 17  11              81.525285
# 18  12              78.936614
# 19  15              82.385960
# 20  16              80.000000
# 21  20              95.000000
# 22  21              67.000000
# 23  22              82.000000
# 24  23              89.000000
# 25  26              95.835542
# 26  27              88.000000
# 27  28              64.000000
# 28  30              79.499360
# 29  19              92.000000

# %%
mydata5=stdn_df.loc[stdn_df['Country']=='US']
mydata5
# Out:
#     ID Last_Name First_Name            City           State  Gender  \
# 9    1     DOE01     JANE01     Los Angeles      California  Female
# 10   2     DOE02     JANE02          Sedona         Arizona  Female
# 11   3     DOE01      JOE01          Elmira        New York    Male
# 12   4     DOE02      JOE02       Lackawana        New York    Male
# 13   5     DOE03      JOE03        Defiance            Ohio    Male
# 14   7     DOE05      JOE05           Cimax  North Carolina    Male
# 15   8     DOE03     JANE03         Liberal          Kansas  Female
# 16  10     DOE05     JANE05        New York        New York  Female
# 17  11     DOE06      JOE06       Hot Coffe     Mississippi    Male
# 18  12     DOE06     JANE06            Java        Virginia  Female
# 19  15     DOE07     JANE07  Drunkard Creek        New York  Female
# 20  16     DOE08     JANE08     Mexican Hat            Utah  Female
# 21  20     DOE09      JOE09        San Juan     Puerto Rico    Male
# ...

# %%
mydata6=stdn_df[stdn_df["Country"].isin(["US","Holland"])]
mydata6
# Out:
#     ID Last_Name First_Name            City           State  Gender  \
# 4   17     DOE09     JANE09       Amsterdam         Holland  Female
# 9    1     DOE01     JANE01     Los Angeles      California  Female
# 10   2     DOE02     JANE02          Sedona         Arizona  Female
# 11   3     DOE01      JOE01          Elmira        New York    Male
# 12   4     DOE02      JOE02       Lackawana        New York    Male
# 13   5     DOE03      JOE03        Defiance            Ohio    Male
# 14   7     DOE05      JOE05           Cimax  North Carolina    Male
# 15   8     DOE03     JANE03         Liberal          Kansas  Female
# 16  10     DOE05     JANE05        New York        New York  Female
# 17  11     DOE06      JOE06       Hot Coffe     Mississippi    Male
# 18  12     DOE06     JANE06            Java        Virginia  Female
# 19  15     DOE07     JANE07  Drunkard Creek        New York  Female
# 20  16     DOE08     JANE08     Mexican Hat            Utah  Female
# ...

# %%
mydata6['Country'].value_counts()
# Out:
# US         20
# Holland     1
# Name: Country, dtype: int64

# %%
mydata7=stdn_df[stdn_df['SAT'] >= 1700]
mydata7
# Out:
#     ID Last_Name First_Name          City           State  Gender  \
# 0   29     DOE14      JOE14  Buenos Aires       Argentina    Male
# 2    9     DOE04     JANE04      Montreal          Canada  Female
# 5    6     DOE04      JOE04      Tel Aviv          Israel    Male
# 6   18     DOE10     JANE10        Mexico          Mexico  Female
# 8   25     DOE11      JOE11     Stockholm          Sweden    Male
# 9    1     DOE01     JANE01   Los Angeles      California  Female
# 10   2     DOE02     JANE02        Sedona         Arizona  Female
# 11   3     DOE01      JOE01        Elmira        New York    Male
# 12   4     DOE02      JOE02     Lackawana        New York    Male
# 13   5     DOE03      JOE03      Defiance            Ohio    Male
# 15   8     DOE03     JANE03       Liberal          Kansas  Female
# 16  10     DOE05     JANE05      New York        New York  Female
# 17  11     DOE06      JOE06     Hot Coffe     Mississippi    Male
# ...

# %%
mydata7=stdn_df[stdn_df['SAT'] >= 1700 & stdn_df['Country'].isin(['US','Holland'])]
mydata7

# %%
std_df1=std_df.loc[:,'ID':'SAT']
std_df1
