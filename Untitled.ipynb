# %%
pwd
# Out:
# 'C:\\Users\\admin\\Python_Prac'

# %%
import os
os.chdir('C:\\Users\\admin\\EDA_Datasets')
os.getcwd()
# Out:
# 'C:\\Users\\admin\\EDA_Datasets'

# %%
import pandas as pd
mydata=pd.read_csv('students.csv')
mydata
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-8-50ed3f54b6fe> in <module>
#       1 import pandas as pd
# ----> 2 mydata=pd.read_csv('students.csv')
#       3 mydata
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
import pandas as pd
mydata=pd.read_excel('students.xls')
mydata
# Out:
#     ID Last Name First Name            City           State  Gender  \
# 0   29     DOE14      JOE14    Buenos Aires       Argentina       0
# 1   13     DOE07      JOE07           Varna        Bulgaria       0
# 2    9     DOE04     JANE04        Montreal          Canada       1
# 3   24     DOE14     JANE14         Beijing           China       1
# 4   17     DOE09     JANE09       Amsterdam         Holland       1
# 5    6     DOE04      JOE04        Tel Aviv          Israel       0
# 6   18     DOE10     JANE10          Mexico          Mexico       1
# 7   14     DOE08      JOE08          Moscow          Russia       0
# 8   25     DOE11      JOE11       Stockholm          Sweden       0
# 9    1     DOE01     JANE01     Los Angeles      California       1
# 10   2     DOE02     JANE02          Sedona         Arizona       1
# 11   3     DOE01      JOE01          Elmira        New York       0
# 12   4     DOE02      JOE02       Lackawana        New York       0
# ...
